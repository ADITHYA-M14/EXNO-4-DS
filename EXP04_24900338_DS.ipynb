# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ls drive/MyDrive/'income(1) (1).csv'
# Out:
# 'drive/MyDrive/income(1) (1).csv'

# %%
ls drive/MyDrive/bmi.csv
# Out:
# drive/MyDrive/bmi.csv

# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
df=pd.read_csv("drive/MyDrive/bmi.csv")
df
# Out:
#      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# ..      ...     ...     ...    ...
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5
#
# [500 rows x 4 columns]

# %%
df.head()
# Out:
#    Gender  Height  Weight  Index
# 0    Male     174      96      4
# 1    Male     189      87      2
# 2  Female     185     110      4
# 3  Female     195     104      3
# 4    Male     149      61      3

# %%
df.dropna()
# Out:
#      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# ..      ...     ...     ...    ...
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5
#
# [500 rows x 4 columns]

# %%
max_vals = np.max(np.abs(df[['Height','Weight']]))
max_vals
max_vals
# Out:
# 199

# %%
df1=pd.read_csv("drive/MyDrive/bmi.csv")
df1
# Out:
#      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# ..      ...     ...     ...    ...
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5
#
# [500 rows x 4 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
df[['Height','Weight']] = sc.fit_transform(df[['Height','Weight']])
df.head(10)
# Out:
#    Gender    Height    Weight  Index
# 0    Male  0.247939 -0.309117      4
# 1    Male  1.164872 -0.587322      2
# 2  Female  0.920357  0.123647      4
# 3  Female  1.531645 -0.061823      3
# 4    Male -1.280283 -1.391027      3
# 5    Male  1.164872 -0.061823      3
# 6    Male -1.402541 -0.432764      5
# 7    Male -0.974639  0.154559      5
# 8    Male  0.247939 -0.494587      3
# 9  Female -0.057706 -0.092735      4

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
Scaler=MinMaxScaler()
df[['Height','Weight']]=Scaler.fit_transform(df[['Height','Weight']])

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [Gender, Height, Weight, Index]
# Index: []

# %%
df2=pd.read_csv("drive/MyDrive/bmi.csv")
df2
# Out:
#      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# ..      ...     ...     ...    ...
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5
#
# [500 rows x 4 columns]

# %%
from sklearn.preprocessing import Normalizer
Scaler=Normalizer()
df2[['Height','Weight']]=Scaler.fit_transform(df2[['Height','Weight']])
df2
# Out:
#      Gender    Height    Weight  Index
# 0      Male  0.875578  0.483077      4
# 1      Male  0.908381  0.418144      2
# 2    Female  0.859536  0.511075      4
# 3    Female  0.882353  0.470588      3
# 4      Male  0.925448  0.378875      3
# ..      ...       ...       ...    ...
# 495  Female  0.700071  0.714073      5
# 496  Female  0.835527  0.549450      4
# 497  Female  0.719753  0.694230      5
# 498    Male  0.844819  0.535052      5
# 499    Male  0.797227  0.603680      5
#
# [500 rows x 4 columns]

# %%
df3=pd.read_csv("drive/MyDrive/bmi.csv")
df3
# Out:
#      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# ..      ...     ...     ...    ...
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5
#
# [500 rows x 4 columns]

# %%
from sklearn.preprocessing import MaxAbsScaler
Scaler=MaxAbsScaler()
df3[['Height','Weight']]=Scaler.fit_transform(df3[['Height','Weight']])
df3
# Out:
#      Gender    Height   Weight  Index
# 0      Male  0.874372  0.60000      4
# 1      Male  0.949749  0.54375      2
# 2    Female  0.929648  0.68750      4
# 3    Female  0.979899  0.65000      3
# 4      Male  0.748744  0.38125      3
# ..      ...       ...      ...    ...
# 495  Female  0.753769  0.95625      5
# 496  Female  0.924623  0.75625      4
# 497  Female  0.708543  0.85000      5
# 498    Male  0.753769  0.59375      5
# 499    Male  0.869347  0.81875      5
#
# [500 rows x 4 columns]

# %%
df4=pd.read_csv("drive/MyDrive/bmi.csv")

# %%
from sklearn.preprocessing import RobustScaler
Scaler=RobustScaler()
df4[['Height','Weight']]=Scaler.fit_transform(df4[['Height','Weight']])
df4.head()
# Out:
#    Gender    Height    Weight  Index
# 0    Male  0.125000 -0.178571      4
# 1    Male  0.660714 -0.339286      2
# 2  Female  0.517857  0.071429      4
# 3  Female  0.875000 -0.035714      3
# 4    Male -0.767857 -0.803571      3

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV,LassoCV,Ridge,Lasso
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import mutual_info_regression
from sklearn.feature_selection import chi2

# %%
import pandas as pd
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
data=pd.read_csv('drive/MyDrive/income(1) (1).csv')

# %%
data=data.dropna()

# %%
df.columns
# Out:
# Index(['Gender', 'Height', 'Weight', 'Index'], dtype='object')

# %%
df
# Out:
#      Gender    Height    Weight  Index
# 0      Male  0.576271  0.418182      4
# 1      Male  0.830508  0.336364      2
# 2    Female  0.762712  0.545455      4
# 3    Female  0.932203  0.490909      3
# 4      Male  0.152542  0.100000      3
# ..      ...       ...       ...    ...
# 495  Female  0.169492  0.936364      5
# 496  Female  0.745763  0.645455      4
# 497  Female  0.016949  0.781818      5
# 498    Male  0.169492  0.409091      5
# 499    Male  0.559322  0.736364      5
#
# [500 rows x 4 columns]

# %%
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency
import seaborn as sns
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
